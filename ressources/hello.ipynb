# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
l = os.listdir()
l = [i for i in l if i.endswith(".csv")]
l = [i for i in l if i.startswith("spac")]
l
# Out:
# ['spaceship-titanic-publicleaderboard-2023-11-01T00:52:39.csv']

# %%
df = pd.read_csv(l[0])
df
# Out:
#       Rank    TeamId                     TeamName   LastSubmissionDate  \
# 0        1   8398674                       CADang  2023-09-17 00:43:44
# 1        2  10309479                         MLCV  2023-10-31 04:34:42
# 2        3   8593894  Involutional Neural Network  2023-09-06 15:23:29
# 3        4  10534604                     Naresh K  2023-10-30 08:03:14
# 4        5   9967377                 Arun K Lenin  2023-09-28 09:09:08
# ...    ...       ...                          ...                  ...
# 2206  2206  11144512       G Harsha Vardhan Reddy  2023-10-28 04:31:36
# 2207  2207  11150511              N.Sriram Radhey  2023-10-29 14:21:02
# 2208  2208  10944678               Alka Chauhan R  2023-10-29 18:30:05
# 2209  2209  11151480                   Sonu Saini  2023-10-30 04:22:19
# 2210  2210  10047196                 JamesStone24  2023-10-30 13:04:49
#
#         Score  SubmissionCount TeamMemberUserNames
# 0     0.96118              152              cadang
# ...

# %%
sns.displot(df.Score)

# %%
_df = df.copy()
_df = _df.loc[_df.Score > 0.5]
_df = _df.loc[_df.Score < 0.83]

# %%
import plotly.express as px

# %%
px.histogram(df, x="Score", nbins=100)

# %%
px.histogram(_df, x="Score", nbins=100)

# %%
_df = df.copy()
_df = _df.loc[_df.Score > 0.774]
_df = _df.loc[_df.Score < 0.83]

# %%
px.histogram(_df, x="Score", nbins=100)
