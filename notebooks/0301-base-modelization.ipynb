# %% [markdown]
# ## OS

# %%
cd ..
# Out:
# /home/alex/tmp/kaggle-spaceship-titanic

# %% [markdown]
# ## Imports

# %%
from src.imports import *
from src.var_transformers import *
from src.class_transformers import *
from src.helpers import *
from src.vars import *
from src.tools import *

# %% [markdown]
# ## Data

# %%
train = pd.read_csv("data/source/train.csv")
test = pd.read_csv("data/source/test.csv")

# %% [markdown]
# ## Split

# %%
X = train.drop("Transported", axis=1)
y = train["Transported"]

# %% [markdown]
# ## pipe and params

# %%
pipeline
# Out:
# Pipeline(steps=[('feat_enhancer', FeatEnhancer()),
#                 ('column_cleaner', ColumnCleaner()),
#                 ('column_selector', ColumnSelector()),
#                 ('log_transformer', LogTransformer()),
#                 ('preprocessor',
#                  ColumnTransformer(transformers=[('passthrough', 'passthrough',
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fa32ed42fb0>),
#                                                  ('cat',
#                                                   Pipeline(steps=[('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fa32ed42ec0>)])),
#                 ('sampler_1', RandomUnderSampler()), ('imputer', KNNImputer()),
#                 ('scaler', StandardScaler()),
#                 ('sampler_2', RandomUnderSampler()),
#                 ('estimator', LogisticRegression())])

# %%
param_grid.keys()
# Out:
# dict_keys(['log_transformer__threshold', 'preprocessor', 'sampler_1', 'sampler_2', 'scaler', 'estimator'])

# %%
for k in param_grid.keys():
    print(k)
    print(param_grid[k])
    print()
# Out:
# log_transformer__threshold
# [0.3, 0.5, 0.75, 1, 1.5]
#
# preprocessor
# [[ColumnTransformer(transformers=[('passthrough', 'passthrough',
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fa340554ee0>)]), ColumnTransformer(transformers=[('knIm',
#                                  Pipeline(steps=[('imputer', KNNImputer())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fa32ed43400>)]), ColumnTransformer(transformers=[('simIm',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fa32ed43520>)]), ColumnTransformer(transformers=[('knIm_sca',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fa32ed436a0>)]), ColumnTransformer(transformers=[('simIm_sca',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fa32ed43820>)]), ColumnTransformer(transformers=[('knIm_sca_pca_60',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.6))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fa32ed439d0>)]), ColumnTransformer(transformers=[('knIm_sca_pca_80',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.8))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fa32ed43b80>)]), ColumnTransformer(transformers=[('knIm_sca_pca_90',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.9))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fa32ed43d30>)]), ColumnTransformer(transformers=[('knIm_sca_pca_95',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.95))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fa32ed43ee0>)]), ColumnTransformer(transformers=[('knIm_sca_pca_99',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.99))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fa32ed43040>)]), ColumnTransformer(transformers=[('passthrough', 'passthrough',
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fa32ed42fb0>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fa32ed42ec0>)]), ColumnTransformer(transformers=[('knIm',
#                                  Pipeline(steps=[('imputer', KNNImputer())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fa32ed42da0>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fa32ed42cb0>)]), ColumnTransformer(transformers=[('simIm',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fa32ed42b90>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fa32ed42aa0>)]), ColumnTransformer(transformers=[('knIm_sca',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fa32ed42920>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fa32ed42830>)]), ColumnTransformer(transformers=[('simIm_sca',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fa32ed426b0>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fa32ed425c0>)]), ColumnTransformer(transformers=[('_knIm_sca_pca_80',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.8))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fa32ed42410>,
#                                  ('cat',
#                                   Pipeline(steps=[('encoder',
#                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fa32ed42320>)),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fa32ed42230>)]), ColumnTransformer(transformers=[('_knIm_sca_pca_90',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.9))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fa32ed42080>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fa32ed41f90>)]), ColumnTransformer(transformers=[('_knIm_sca_pca_95',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.95))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fa32ed41de0>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fa32ed41cf0>)]), ColumnTransformer(transformers=[('_knIm_sca_pca_99',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.99))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fa32ed41b40>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fa32ed41a50>)])]]
#
# sampler_1
# ['passthrough']
#
# sampler_2
# [RandomUnderSampler()]
#
# scaler
# ['passthrough', StandardScaler(), RobustScaler(), Normalizer(), QuantileTransformer(n_quantiles=100)]
#
# estimator
# [LogisticRegression()]

# %%
# grid 
grid = GridSearchCV(
    pipeline,
    param_grid,
    # cv=cv(n=10, test_size=0.2),
    cv=2,
    scoring="accuracy",
    n_jobs=12,
    return_train_score=True,
    verbose=1,
    refit=True,
    
)

# %% [markdown]
# ## Train

# %%
# fit
grid.fit(X, y)
# Out:
# Fitting 2 folds for each of 25 candidates, totalling 50 fits
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/alex/tmp/kaggle-spaceship-titanic/notebooks/0301-base-modelization.ipynb Cell 15 line 2
#       <a href='vscode-notebook-cell:/home/alex/tmp/kaggle-spaceship-titanic/notebooks/0301-base-modelization.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> # fit
# ----> <a href='vscode-notebook-cell:/home/alex/tmp/kaggle-spaceship-titanic/notebooks/0301-base-modelization.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> grid.fit(X, y)
#
# File ~/tmp/kaggle-spaceship-titanic/.venv/lib/python3.10/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/tmp/kaggle-spaceship-titanic/.venv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File ~/tmp/kaggle-spaceship-titanic/.venv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:1422, in GridSearchCV._run_search(self, evaluate_candidates)
#    1420 def _run_search(self, evaluate_candidates):
#    1421     """Search all candidates in param_grid"""
# -> 1422     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/tmp/kaggle-spaceship-titanic/.venv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:875, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     868 elif len(out) != n_candidates * n_splits:
#     869     raise ValueError(
#     870         "cv.split and cv.get_n_splits returned "
#     871         "inconsistent results. Expected {} "
#     872         "splits, got {}".format(n_splits, len(out) // n_candidates)
#     873     )
# --> 875 _warn_or_raise_about_fit_failures(out, self.error_score)
#     877 # For callable self.scoring, the return type is only know after
#     878 # calling. If the return type is a dictionary, the error scores
#     879 # can now be inserted with the correct key. The type checking
#     880 # of out will be done in `_insert_error_scores`.
#     881 if callable(self.scoring):
#
# File ~/tmp/kaggle-spaceship-titanic/.venv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:414, in _warn_or_raise_about_fit_failures(results, error_score)
#     407 if num_failed_fits == num_fits:
#     408     all_fits_failed_message = (
#     409         f"\nAll the {num_fits} fits failed.\n"
#     410         "It is very likely that your model is misconfigured.\n"
#     411         "You can try to debug the error by setting error_score='raise'.\n\n"
#     412         f"Below are more details about the failures:\n{fit_errors_summary}"
#     413     )
# --> 414     raise ValueError(all_fits_failed_message)
#     416 else:
#     417     some_fits_failed_message = (
#     418         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     419         "The score on these train-test partitions for these parameters"
#    (...)
#     423         f"Below are more details about the failures:\n{fit_errors_summary}"
#     424     )
#
# ValueError:
# All the 50 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/alex/tmp/kaggle-spaceship-titanic/.venv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/alex/tmp/kaggle-spaceship-titanic/.venv/lib/python3.10/site-packages/imblearn/pipeline.py", line 293, in fit
#     Xt, yt = self._fit(X, y, **fit_params_steps)
#   File "/home/alex/tmp/kaggle-spaceship-titanic/.venv/lib/python3.10/site-packages/imblearn/pipeline.py", line 211, in _fit
#     self._validate_steps()
#   File "/home/alex/tmp/kaggle-spaceship-titanic/.venv/lib/python3.10/site-packages/imblearn/pipeline.py", line 160, in _validate_steps
#     raise TypeError(
# TypeError: All intermediate steps of the chain should be estimators that implement fit and transform or fit_resample (but not both) or be a string 'passthrough' '[ColumnTransformer(transformers=[('passthrough', 'passthrough',
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0d7a5a8d00>)]), ColumnTransformer(transformers=[('knIm',
#                                  Pipeline(steps=[('imputer', KNNImputer())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0d7a5a8f10>)]), ColumnTransformer(transformers=[('simIm',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0d7a5a8f70>)]), ColumnTransformer(transformers=[('knIm_sca',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0d7a5a8fa0>)]), ColumnTransformer(transformers=[('simIm_sca',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0d7a5a8e80>)]), ColumnTransformer(transformers=[('knIm_sca_pca_60',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.6))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0d7a5a9090>)]), ColumnTransformer(transformers=[('knIm_sca_pca_80',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.8))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0d7a5a9870>)]), ColumnTransformer(transformers=[('knIm_sca_pca_90',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.9))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0d7a5a9840>)]), ColumnTransformer(transformers=[('knIm_sca_pca_95',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.95))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0d7a5aa260>)]), ColumnTransformer(transformers=[('knIm_sca_pca_99',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.99))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0d7a5aa530>)]), ColumnTransformer(transformers=[('passthrough', 'passthrough',
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0d7a5aa2c0>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0d7a5aa4d0>)]), ColumnTransformer(transformers=[('knIm',
#                                  Pipeline(steps=[('imputer', KNNImputer())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0d7a5aa500>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0d7a5a8100>)]), ColumnTransformer(transformers=[('simIm',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0d7a5a8130>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0d7a5aab60>)]), ColumnTransformer(transformers=[('knIm_sca',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0d7a5aaa40>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0d7a5aaa70>)]), ColumnTransformer(transformers=[('simIm_sca',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0d7a5a8520>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0d7a5ab130>)]), ColumnTransformer(transformers=[('_knIm_sca_pca_80',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.8))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0d7a5aae90>,
#                                  ('cat',
#                                   Pipeline(steps=[('encoder',
#                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f0d7a5ab790>)),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0d7a5ab160>)]), ColumnTransformer(transformers=[('_knIm_sca_pca_90',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.9))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0d7a5a8880>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0d7a5a8910>)]), ColumnTransformer(transformers=[('_knIm_sca_pca_95',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.95))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0d7a5abd00>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0d7a5abbb0>)]), ColumnTransformer(transformers=[('_knIm_sca_pca_99',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.99))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0d7a5a8550>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0d7a5ab970>)])]' (type <class 'list'>) doesn't)
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/alex/tmp/kaggle-spaceship-titanic/.venv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/alex/tmp/kaggle-spaceship-titanic/.venv/lib/python3.10/site-packages/imblearn/pipeline.py", line 293, in fit
#     Xt, yt = self._fit(X, y, **fit_params_steps)
#   File "/home/alex/tmp/kaggle-spaceship-titanic/.venv/lib/python3.10/site-packages/imblearn/pipeline.py", line 211, in _fit
#     self._validate_steps()
#   File "/home/alex/tmp/kaggle-spaceship-titanic/.venv/lib/python3.10/site-packages/imblearn/pipeline.py", line 160, in _validate_steps
#     raise TypeError(
# TypeError: All intermediate steps of the chain should be estimators that implement fit and transform or fit_resample (but not both) or be a string 'passthrough' '[ColumnTransformer(transformers=[('passthrough', 'passthrough',
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7ff97c0ce5f0>)]), ColumnTransformer(transformers=[('knIm',
#                                  Pipeline(steps=[('imputer', KNNImputer())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7ff97c0ce620>)]), ColumnTransformer(transformers=[('simIm',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7ff97c0ce710>)]), ColumnTransformer(transformers=[('knIm_sca',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7ff97c0ce890>)]), ColumnTransformer(transformers=[('simIm_sca',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7ff97c0cea10>)]), ColumnTransformer(transformers=[('knIm_sca_pca_60',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.6))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7ff97c0ceb90>)]), ColumnTransformer(transformers=[('knIm_sca_pca_80',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.8))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7ff97c0ced10>)]), ColumnTransformer(transformers=[('knIm_sca_pca_90',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.9))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7ff97c0ceec0>)]), ColumnTransformer(transformers=[('knIm_sca_pca_95',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.95))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7ff97c0cf070>)]), ColumnTransformer(transformers=[('knIm_sca_pca_99',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.99))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7ff97c0cf220>)]), ColumnTransformer(transformers=[('passthrough', 'passthrough',
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7ff97c0cf310>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7ff97c0cf280>)]), ColumnTransformer(transformers=[('knIm',
#                                  Pipeline(steps=[('imputer', KNNImputer())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7ff97c0cf520>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7ff97c0cf5b0>)]), ColumnTransformer(transformers=[('simIm',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7ff97c0cf730>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7ff97c0cf7c0>)]), ColumnTransformer(transformers=[('knIm_sca',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7ff97c0cf940>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7ff97c0cf9d0>)]), ColumnTransformer(transformers=[('simIm_sca',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7ff97c0cfbb0>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7ff97c0cfc40>)]), ColumnTransformer(transformers=[('_knIm_sca_pca_80',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.8))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7ff97c0cfe20>,
#                                  ('cat',
#                                   Pipeline(steps=[('encoder',
#                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ff97c0cdff0>)),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7ff97c0cfeb0>)]), ColumnTransformer(transformers=[('_knIm_sca_pca_90',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.9))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7ff97c0ce230>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7ff97c0ce080>)]), ColumnTransformer(transformers=[('_knIm_sca_pca_95',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.95))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7ff97c108250>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7ff97c1082b0>)]), ColumnTransformer(transformers=[('_knIm_sca_pca_99',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.99))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7ff97c108040>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7ff97c108190>)])]' (type <class 'list'>) doesn't)
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/alex/tmp/kaggle-spaceship-titanic/.venv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/alex/tmp/kaggle-spaceship-titanic/.venv/lib/python3.10/site-packages/imblearn/pipeline.py", line 293, in fit
#     Xt, yt = self._fit(X, y, **fit_params_steps)
#   File "/home/alex/tmp/kaggle-spaceship-titanic/.venv/lib/python3.10/site-packages/imblearn/pipeline.py", line 211, in _fit
#     self._validate_steps()
#   File "/home/alex/tmp/kaggle-spaceship-titanic/.venv/lib/python3.10/site-packages/imblearn/pipeline.py", line 160, in _validate_steps
#     raise TypeError(
# TypeError: All intermediate steps of the chain should be estimators that implement fit and transform or fit_resample (but not both) or be a string 'passthrough' '[ColumnTransformer(transformers=[('passthrough', 'passthrough',
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f35a98490>)]), ColumnTransformer(transformers=[('knIm',
#                                  Pipeline(steps=[('imputer', KNNImputer())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f35a9a620>)]), ColumnTransformer(transformers=[('simIm',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f35a9b160>)]), ColumnTransformer(transformers=[('knIm_sca',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f35a98520>)]), ColumnTransformer(transformers=[('simIm_sca',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f35a98160>)]), ColumnTransformer(transformers=[('knIm_sca_pca_60',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.6))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f35a98910>)]), ColumnTransformer(transformers=[('knIm_sca_pca_80',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.8))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f35a9ba00>)]), ColumnTransformer(transformers=[('knIm_sca_pca_90',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.9))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f35a988e0>)]), ColumnTransformer(transformers=[('knIm_sca_pca_95',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.95))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f35a985e0>)]), ColumnTransformer(transformers=[('knIm_sca_pca_99',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.99))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f35a98b50>)]), ColumnTransformer(transformers=[('passthrough', 'passthrough',
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f35a9bf70>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f35a98bb0>)]), ColumnTransformer(transformers=[('knIm',
#                                  Pipeline(steps=[('imputer', KNNImputer())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f35a99930>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f35a98e50>)]), ColumnTransformer(transformers=[('simIm',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f35a99060>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f35a98f10>)]), ColumnTransformer(transformers=[('knIm_sca',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f35a99030>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f5c5d81f0>)]), ColumnTransformer(transformers=[('simIm_sca',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f5c5d8100>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f5c5d8190>)]), ColumnTransformer(transformers=[('_knIm_sca_pca_80',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.8))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f5c5d88b0>,
#                                  ('cat',
#                                   Pipeline(steps=[('encoder',
#                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f5c5d87f0>)),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f5c5d85e0>)]), ColumnTransformer(transformers=[('_knIm_sca_pca_90',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.9))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f5c5d8a30>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f5c5d8c70>)]), ColumnTransformer(transformers=[('_knIm_sca_pca_95',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.95))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f5c5d8e50>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f5c5d8d00>)]), ColumnTransformer(transformers=[('_knIm_sca_pca_99',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.99))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f5c5d90c0>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f5c5d9120>)])]' (type <class 'list'>) doesn't)
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/alex/tmp/kaggle-spaceship-titanic/.venv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/alex/tmp/kaggle-spaceship-titanic/.venv/lib/python3.10/site-packages/imblearn/pipeline.py", line 293, in fit
#     Xt, yt = self._fit(X, y, **fit_params_steps)
#   File "/home/alex/tmp/kaggle-spaceship-titanic/.venv/lib/python3.10/site-packages/imblearn/pipeline.py", line 211, in _fit
#     self._validate_steps()
#   File "/home/alex/tmp/kaggle-spaceship-titanic/.venv/lib/python3.10/site-packages/imblearn/pipeline.py", line 160, in _validate_steps
#     raise TypeError(
# TypeError: All intermediate steps of the chain should be estimators that implement fit and transform or fit_resample (but not both) or be a string 'passthrough' '[ColumnTransformer(transformers=[('passthrough', 'passthrough',
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f968ef31150>)]), ColumnTransformer(transformers=[('knIm',
#                                  Pipeline(steps=[('imputer', KNNImputer())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f968ef30fa0>)]), ColumnTransformer(transformers=[('simIm',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f968ef31930>)]), ColumnTransformer(transformers=[('knIm_sca',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f968ef31ea0>)]), ColumnTransformer(transformers=[('simIm_sca',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f968ef31ff0>)]), ColumnTransformer(transformers=[('knIm_sca_pca_60',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.6))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f968ef32680>)]), ColumnTransformer(transformers=[('knIm_sca_pca_80',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.8))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f968ef320e0>)]), ColumnTransformer(transformers=[('knIm_sca_pca_90',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.9))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f968ef324d0>)]), ColumnTransformer(transformers=[('knIm_sca_pca_95',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.95))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f968ef326b0>)]), ColumnTransformer(transformers=[('knIm_sca_pca_99',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.99))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f968ef335b0>)]), ColumnTransformer(transformers=[('passthrough', 'passthrough',
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f968ef30310>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f968ef30100>)]), ColumnTransformer(transformers=[('knIm',
#                                  Pipeline(steps=[('imputer', KNNImputer())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f968ef331c0>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f968ef336d0>)]), ColumnTransformer(transformers=[('simIm',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f968ef33700>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f968ef33880>)]), ColumnTransformer(transformers=[('knIm_sca',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f968ef33ac0>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f968ef33160>)]), ColumnTransformer(transformers=[('simIm_sca',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f968ef33910>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f968ef32e90>)]), ColumnTransformer(transformers=[('_knIm_sca_pca_80',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.8))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f968ef33d60>,
#                                  ('cat',
#                                   Pipeline(steps=[('encoder',
#                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f968ef33f10>)),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f968ef307f0>)]), ColumnTransformer(transformers=[('_knIm_sca_pca_90',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.9))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f968ef30c10>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f968f5958a0>)]), ColumnTransformer(transformers=[('_knIm_sca_pca_95',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.95))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f968eee01f0>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
# ...
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f5c79bd30>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f5c79ba90>)]), ColumnTransformer(transformers=[('simIm_sca',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f5c79b220>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f5c79afb0>)]), ColumnTransformer(transformers=[('_knIm_sca_pca_80',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.8))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f5c79b550>,
#                                  ('cat',
#                                   Pipeline(steps=[('encoder',
#                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f5c79b610>)),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f5c79b190>)]), ColumnTransformer(transformers=[('_knIm_sca_pca_90',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.9))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f5c79b760>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f5c79b9d0>)]), ColumnTransformer(transformers=[('_knIm_sca_pca_95',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.95))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f35a98bb0>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f35a992a0>)]), ColumnTransformer(transformers=[('_knIm_sca_pca_99',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.99))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f35a98ca0>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f3f35a99390>)])]' (type <class 'list'>) doesn't)
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/alex/tmp/kaggle-spaceship-titanic/.venv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/alex/tmp/kaggle-spaceship-titanic/.venv/lib/python3.10/site-packages/imblearn/pipeline.py", line 293, in fit
#     Xt, yt = self._fit(X, y, **fit_params_steps)
#   File "/home/alex/tmp/kaggle-spaceship-titanic/.venv/lib/python3.10/site-packages/imblearn/pipeline.py", line 211, in _fit
#     self._validate_steps()
#   File "/home/alex/tmp/kaggle-spaceship-titanic/.venv/lib/python3.10/site-packages/imblearn/pipeline.py", line 160, in _validate_steps
#     raise TypeError(
# TypeError: All intermediate steps of the chain should be estimators that implement fit and transform or fit_resample (but not both) or be a string 'passthrough' '[ColumnTransformer(transformers=[('passthrough', 'passthrough',
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0db224fc40>)]), ColumnTransformer(transformers=[('knIm',
#                                  Pipeline(steps=[('imputer', KNNImputer())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0db224fc70>)]), ColumnTransformer(transformers=[('simIm',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0db224fd60>)]), ColumnTransformer(transformers=[('knIm_sca',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0db224ff10>)]), ColumnTransformer(transformers=[('simIm_sca',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0db224d930>)]), ColumnTransformer(transformers=[('knIm_sca_pca_60',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.6))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0db224df30>)]), ColumnTransformer(transformers=[('knIm_sca_pca_80',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.8))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0db224dae0>)]), ColumnTransformer(transformers=[('knIm_sca_pca_90',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.9))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0db224e170>)]), ColumnTransformer(transformers=[('knIm_sca_pca_95',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.95))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0db224e410>)]), ColumnTransformer(transformers=[('knIm_sca_pca_99',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.99))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0db224ea10>)]), ColumnTransformer(transformers=[('passthrough', 'passthrough',
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0db224e590>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0db224e9e0>)]), ColumnTransformer(transformers=[('knIm',
#                                  Pipeline(steps=[('imputer', KNNImputer())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0db224e6b0>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0db224e830>)]), ColumnTransformer(transformers=[('simIm',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0db224e9b0>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0db224eb30>)]), ColumnTransformer(transformers=[('knIm_sca',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0db224efe0>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0db207c190>)]), ColumnTransformer(transformers=[('simIm_sca',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0db207c2b0>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0db207c100>)]), ColumnTransformer(transformers=[('_knIm_sca_pca_80',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.8))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0db207c430>,
#                                  ('cat',
#                                   Pipeline(steps=[('encoder',
#                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f0db207c790>)),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0db207c910>)]), ColumnTransformer(transformers=[('_knIm_sca_pca_90',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.9))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0db207c6d0>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0db207c2e0>)]), ColumnTransformer(transformers=[('_knIm_sca_pca_95',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.95))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0db207cc70>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0db207ce50>)]), ColumnTransformer(transformers=[('_knIm_sca_pca_99',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler()),
#                                                  ('pca',
#                                                   PCA(n_components=0.99))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0db207d330>),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f0db207d270>)])]' (type <class 'list'>) doesn't)

# %%
# results
res = resultize(grid)

# save & push
save_predict_all(grid)
commit_push(res.mean_test_score.iloc[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/alex/tmp/kaggle-spaceship-titanic/notebooks/0301-base-modelization.ipynb Cell 16 line 2
#       <a href='vscode-notebook-cell:/home/alex/tmp/kaggle-spaceship-titanic/notebooks/0301-base-modelization.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> # results
# ----> <a href='vscode-notebook-cell:/home/alex/tmp/kaggle-spaceship-titanic/notebooks/0301-base-modelization.ipynb#X42sZmlsZQ%3D%3D?line=1'>2</a> res = resultize(grid)
#       <a href='vscode-notebook-cell:/home/alex/tmp/kaggle-spaceship-titanic/notebooks/0301-base-modelization.ipynb#X42sZmlsZQ%3D%3D?line=3'>4</a> # save & push
#       <a href='vscode-notebook-cell:/home/alex/tmp/kaggle-spaceship-titanic/notebooks/0301-base-modelization.ipynb#X42sZmlsZQ%3D%3D?line=4'>5</a> save_predict_all(grid)
#
# File ~/tmp/kaggle-spaceship-titanic/src/tools.py:22, in resultize(grid, head)
#      16 def resultize(
#      17     grid: GridSearchCV,
#      18     head: int = 10,
#      19 ) -> pd.DataFrame:
#      20     """Build a dataframe from the results of a grid search."""
# ---> 22     res = grid.cv_results_
#      23     res = pd.DataFrame(res)
#      25     res = res.sort_values(by="rank_test_score")
#
# AttributeError: 'GridSearchCV' object has no attribute 'cv_results_'

# %%
1/0

# %%
# # grid 2
# grid_2 = GridSearchCV(
#     pipeline,
#     param_grid,
#     cv=10,
#     scoring="accuracy",
#     n_jobs=12,
#     return_train_score=True,
#     verbose=2,
#     refit=True,   
# )

# # fit
# grid_2.fit(X, y)

# # results
# res_2 = resultize(grid_2)

# # save & push
# save_predict_all(grid_2)
# commit_push(res_2.mean_test_score.iloc[0])

# # display
# res_2

# %%
1/0

# %% [markdown]
# ## fine tuning

# %%
preprocessor = grid.best_estimator_[:-2]
preprocessor

# %%
_X = preprocessor.transform(X)
_X

# %%
pipeline_fine = Pipeline(
    [
        ("sampler", RandomUnderSampler()),
        ("estimator", RandomForestClassifier()),
    ]
)

# %%
param_grid_fine = {
    "estimator__n_estimators": [ 40, 80, 160, 320, 640, 1280],
    # "estimator__max_depth": [None,  4, 8, 16, 32, 64, 128],
    # "estimator__min_samples_split": [ None, 4,  8, 16, 32, 64, 129],
    # "estimator__oob_score": [True, False],
    # "estimator__criterion": ["gini" ], # "entropy", "log_loss"
}

# %%
cardinality(param_grid_fine)

# %%
grid_fine = HalvingGridSearchCV(
    pipeline_fine,
    param_grid_fine,
    cv=5,
    scoring="accuracy",
    n_jobs=12,
    return_train_score=True,
    verbose=1,
    refit=True,
    aggressive_elimination=True,
    
)
grid_fine

# %%
grid_fine.fit(_X, y)

# %%
grid_fine.best_estimator_

# %%
res_fine = resultize(grid_fine)
res_fine
